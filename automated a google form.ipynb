# %% [markdown]
# requirements or Pre installed liberaries:
#     python selenium.
#
# required driver:
#     i have done it with moicrosoft edge driver.
#     you can check other drivers that are provided at selenium page-
#     https://pypi.org/project/selenium/

# %% [markdown]
# I have used lists to store the questions and their corresponding answers as it makes the execution better while looping over multiple variables and finding similar strings.
#
# you can use dictionary too.

# %%
# list of questions
que = ['Simant has recently joined as the Head of the sales team of a company which manufactures solar lamps. He has been given a tough target to sell 10,000 units in 3 months in rural India. Which of these goals can he focus on to ensure that he meets the tough target?',
       'Gehul’s assignment deadline is tomorrow and there is a lot to be done yet. If he focuses on doing a perfect assignment he cannot submit it on time. Which of the following thinking shows solution thinking?',
       'Your friend Adin wants to start a business but even before starting he is already very scared about failing in his new venture. He has come to you seeking help, what will you advise him?',
       'A local clinic decided to organize an AIDS campaign in the nearby slum areas. While setting up the campaign, the team faced aggressive opposition from the people living in the area. Which of the following team members are thinking solutions?',
       'The mayor of the city has set up a committee to come up with a solution on how to control the cases of Covid in the city. Who will you choose as the chief of the panel?',
       'Your younger brother is in the first year of engineering. He finds Chemistry tough to understand. What would you suggest to him?',
       'Kayla has recently moved to a new city for her college, but she has been falling ill every night because of the change in food, water, climate etc. What should she do? ',
       'In spite of undertaking sufficient measures, farmers continue facing severe problems like low production, poor quality etc. every year in our country. This means that -',
       'Loukit and his roommates notice that the water dispenser installed in their hostel is not cleaned regularly. If they think like solution designers, how will they approach this situation?',
       'Two medical researchers are trying to develop a vaccine for a new kind of disease that has been spreading rapidly. Which of these approaches do you agree with?',
       'Sohain has been given a complex Mathematics assignment to complete. He doesn’t know where to start and submission date is coming soon. Which approach should he take to complete it as a Contributor?',
       'Falguni, an electronics engineer, has come up with an idea of building a product that would make common check-ups easily available at the patients’ home but she knows that the product will be difficult to build. How can she approach this situation?',
       'Just an hour before the final show, Pormin, a dress designer, sees that there is a minor fault in one of his dresses. What should he do?',
       "Your friend has made a short film on 'life in a college campus'. He wants you to see and give feedback for film. What are you likely to ask him?",
       'Your friend Ondrila is assigned a project topic that she finds boring. What will you suggest to her?',
       'Zirdaus has been asked to do market research for a new product. Now the work has started to become exhausting. What do you think Zirdaus could tell herself to keep going?',
       'Somank owns a huge cloth making factory but he personally checks every batch of cloth before dispatching it. Why do you think he does that?',
       "Which of these show a deep engagement approach to one's career?",
       'As a software developer working on the digital paper correction system, Patang should ensure that –',
       'Divyambar has been asked to make a report on the progress in the latest project undertaken by the company and asked to give an estimate of when he is likely to finish it. Which of these approaches would he take, if he is a ‘Contributor deep diver’?',
       'Tori runs a food mess for hostellers. During holidays many students choose to stay back to do extra courses and internships. If she sees it as an opportunity to add value, which of these will she not do?',
       'During her vacations, Leya volunteers at an NGO which works to protect parks and gardens in her city. Which reason shows that she is focusing on value for others?',
       "Many telecom companies are trying to take internet services to rural India. Which of these reasons for taking up the initiative shows that company is recognizing the deeper value of service for the company?",
       "A local coaching center built an open platform to provide recorded lectures and study material free of cost to all the students. Which of these reasons show a value of service for the coaching center?",
       "In an advertisement, a coffee house, shows the full journey of coffee from careful selection of coffee beans to finally serving it to customers. Why do you think that the company is giving so much importance to the journey of coffee?",
       "Vidur likes to review TV shows and shares with his friends. They suggest him to start a YouTube channel. If he was a contributor, what form of value would he focus on?",
       "After a rigorous selection process, a steel company selected a few employees for a 3-month tour to top steel manufacturing countries to study the latest in the field. Which of them got self-growth value out of the experience?",
       "Tenzing, a police officer, notices that a candidate of a political party is forcing people to cast their votes for him. She decides to take immediate action against it. Why do you think she does this?",
       ]
# list of their corresponding answers
ans = ['The goal of helping villagers understand the benefits of using solar lamps so that he can create the need to reach the target without fail.',
       'How do I submit on time an assignment that I’ll be proud to call mine?',
       '“There is a lot of trial and error in taking a new idea and building a business around it. You may not get it right the first time, but that’s okay. You would still be moving forward”.',
       'Pomeli: “Let us find out why these people are opposing the drive and then find a suitable way to re-design the campaign.”',
       'Ms. Jhanvi: “We need to control the outbreak and protect the people. Let’s put aside our comforts and do what has to be done to ensure that.”',
       'Right now you think that Chemistry is hard to understand. Why not challenge yourself to love the subject?',
       'She can search for different ways to make herself healthy so that she can adjust to the new climate soon. ',
       'We now need to find new ways to solve the problem to do away with the problem once for all.',
       'Form a team and find different ways of cleaning the dispenser and ensure that it stays clean throughout.',
       'Kauli- “I need to try different combinations of active drugs simultaneously and keep testing them till I reach the results.”',
       'He could break up the assignment into small components and solve each one systematically.',
       'She can take guidance from her seniors and other experts and find different ways to build the product.',
       'Alter it so that the dress is perfect.',
       '“What kind of inputs do you want? I will keep that in mind while watching the film.”',
       '“Find out the relevance and importance of the assigned topic so that it is of interest to you.”',
       '“Let me look at the kind of insights that are coming to keep me energized. After all, this research will be useful for the product launch.”',
       'He wants to ensure that every product made in his factory is of high quality and standard.',
       'Develop a genuine love and curiosity for whatever career/ field you take up.',
       'The software works reliably each time, every time.',
       'He finds out the purpose of the report and details needed in it like the right people to work on it and their availability, where would he get his data from, etc. He then creates a broad work approach before he decides on time estimate.',
       'Request the college management for permission to increase the cost of food items on the menu as she is extending her services during vacation.',
       "These spaces are important and must be taken care of.",
       "This initiative will open up new ways of doing business, learning and communicating in rural areas.",
       "They wanted to help students who otherwise don’t have access to coaching centers.",
       "So that every coffee drinker understands what goes behind the making of coffee and values it.",
       "That people can benefit from his reviews and popularity, and invest their time only in the shows they like.",
       "Susan: “Now I know I can do so much more in my role.”",
       "Her action can make a difference to the issue."]

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time
from time import sleep
driver = webdriver.Edge(executable_path = 'C:\\Users\\Hell-Raiser\\Desktop\\shreyu cpdp\\edgedriver_win64\\msedgedriver.exe')

driver.get("https://docs.google.com/forms/d/e/1FAIpQLSeqqhByDMBh3S3he8g5ARw4OveeSr6SjV1kaQBMoHW0JdsFqA/viewform")

inttt=True
tq=1
while(inttt):
    try:
        while(tq <= 19):
            q = driver.find_element_by_xpath('/html/body/div/div[2]/form/div[2]/div/div[2]/div[{}]/div/div/div[1]/div[1]/div[1]'.format(tq))
            x = q.text
            x=x[:-1]
            for i in range(0,len(que)):
                if (que[i] in x):
                    an = i
            for i in range(1,4):
                op = driver.find_element_by_xpath('/html/body/div/div[2]/form/div[2]/div/div[2]/div[{}]/div/div/div[2]/div/div/span/div/div[{}]/label/div/div[2]'.format(tq,i)).text
                if(ans[an] in op):
                    op = driver.find_element_by_xpath('/html/body/div/div[2]/form/div[2]/div/div[2]/div[{}]/div/div/div[2]/div/div/span/div/div[{}]/label/div/div[1]/div/div[3]'.format(tq,i)).click()
            tq=tq+1
            #print(tq)
            if(tq==19):
                inttt=False
    except NoSuchElementException:
        #print("in exp - ",tq)
        tq=tq+1
        if(tq==19):
            inttt=False
